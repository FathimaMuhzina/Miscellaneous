# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#To see maximum no of columns
pd.pandas.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # 1. Missing Values

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
features_with_na=[features for features in df.columns if df[features].isna().sum()>0]
len(features_with_na)
# Out:
# 19

# %%
#To find the % of missing values

# %%
for features in features_with_na:
    print(features,np.round(df[features].isnull().mean(),2),'% missing values')
# Out:
# LotFrontage 0.18 % missing values
# Alley 0.94 % missing values
# MasVnrType 0.01 % missing values
# MasVnrArea 0.01 % missing values
# BsmtQual 0.03 % missing values
# BsmtCond 0.03 % missing values
# BsmtExposure 0.03 % missing values
# BsmtFinType1 0.03 % missing values
# BsmtFinType2 0.03 % missing values
# Electrical 0.0 % missing values
# FireplaceQu 0.47 % missing values
# GarageType 0.06 % missing values
# GarageYrBlt 0.06 % missing values
# GarageFinish 0.06 % missing values
# GarageQual 0.06 % missing values
# GarageCond 0.06 % missing values
# PoolQC 1.0 % missing values
# Fence 0.81 % missing values
# MiscFeature 0.96 % missing values

# %% [markdown]
# Since there are so many missing values, we need to find out if there is any relationship between the null values and the dependant variable[SalesPrice].
# For that, we plot scatter plot.

# %%
for features in features_with_na:
    data=df.copy()
    #Creating a variable which indicates 1 for null value and 0 for other values
    data[features] = np.where(data[features].isnull(),1,0)
    
    data.groupby(features)['SalePrice'].median().plot.bar()
    plt.title(features)
    plt.show()

# %% [markdown]
# The inference from these graphs are there are some relationship between the null values and SalePrice. Hence the same has to be filled in with some meaningful values.

# %% [markdown]
# # 2.Check out all the Numerical Variables

# %%
numerical_features =[feature for feature in df.columns if df[feature].dtypes != 'O']
numerical_features
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
len(numerical_features)
# Out:
# 38

# %%
df[numerical_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
#Separate all year columns

# %%
year_features=[feature for feature in numerical_features if 'Yr' in feature or 'Year' in feature]
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_features:
    print(feature,df[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
for feature in year_features:
    print(feature,len(df[feature].unique()))
# Out:
# YearBuilt 112
# YearRemodAdd 61
# GarageYrBlt 98
# YrSold 5

# %%
#Checking for relationship between YrSold and Dependant feature

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title('House Price Vs Year Sold')
# Out:
# Text(0.5, 1.0, 'House Price Vs Year Sold')

# %%
#Check the relationship of all year data with SalePrice

for feature in year_features:
    if feature!='YrSold':
        data = df.copy()
        
        data[feature] = data['YrSold']- data[feature]
        
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
#Checking for discrete values
discrete_features=[feature for feature in numerical_features if len(df[feature].unique())<25 and feature not in year_features+['Id']]
len(discrete_features)
# Out:
# 17

# %%
#Find the relationship between discrete features and SalePrice
for features in discrete_features:
    data=df.copy()
    df.groupby(features)['SalePrice'].median().plot.bar()
    plt.xlabel(features)
    plt.ylabel('SalePrice')
    plt.title(features)
    plt.show()

# %% [markdown]
# So we have concluded that there is a reationship between the discrete numerical features and SalePrice

# %% [markdown]
# # 3.Distribution of Numerical Variables

# %%
#Checking Continuous numerical features
cont_features=[features for features in numerical_features if features not in year_features+discrete_features+['Id']]
len(cont_features)
# Out:
# 16

# %%
for features in cont_features:
    data =df.copy()
    data[features].hist(bins=25)
    plt.xlabel(features)
    plt.ylabel('SalePrice')
    plt.title(features)
    plt.show()

# %%
for feature in cont_features:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else: 
        data[feature]=np.log(data[feature])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
for feature in cont_features:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else: 
        data[feature].hist(bins=25)
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# # Outliers

# %%
for feature in cont_features:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else: 
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# # 4.Check out all the Categorical Variables

# %% [markdown]
# # 5.Cardinality of Categorical Variables

# %% [markdown]
# # 6. Reationship independent and dependant features
